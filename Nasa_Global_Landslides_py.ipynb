# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Global_Landslide_Catalog_Export.csv')
df
# Out:
#               source_name                                        source_link  \
# 0                     AGU  https://blogs.agu.org/landslideblog/2008/10/14...
# 1               Oregonian  http://www.oregonlive.com/news/index.ssf/2009/...
# 2                CBS News  https://www.cbsnews.com/news/dozens-missing-af...
# 3                 Reuters  https://in.reuters.com/article/idINIndia-41450...
# 4             The Freeman  http://www.philstar.com/cebu-news/621414/lands...
# ...                   ...                                                ...
# 11028    The Jakarta Post  http://www.thejakartapost.com/news/2017/04/02/...
# 11029     Greater Kashmir  http://www.greaterkashmir.com/news/jammu/lands...
# 11030           NBC Daily  http://www.nbcdaily.com/separate-landslides-ki...
# 11031  AGU Landslide Blog  http://blogs.agu.org/landslideblog/2017/05/02/...
# 11032  The Times of India  https://timesofindia.indiatimes.com/city/hyder...
#
# ...

# %%
df.head(5)
# Out:
#    source_name                                        source_link  event_id  \
# 0          AGU  https://blogs.agu.org/landslideblog/2008/10/14...       684
# 1    Oregonian  http://www.oregonlive.com/news/index.ssf/2009/...       956
# 2     CBS News  https://www.cbsnews.com/news/dozens-missing-af...       973
# 3      Reuters  https://in.reuters.com/article/idINIndia-41450...      1067
# 4  The Freeman  http://www.philstar.com/cebu-news/621414/lands...      2603
#
#                event_date  event_time  \
# 0  08/01/2008 12:00:00 AM         NaN
# 1  01/02/2009 02:00:00 AM         NaN
# 2  01/19/2007 12:00:00 AM         NaN
# 3  07/31/2009 12:00:00 AM         NaN
# 4  10/16/2010 12:00:00 PM         NaN
#
#                                          event_title  \
# 0      Sigou Village, Loufan County, Shanxi Province
# 1                                Lake Oswego, Oregon
# 2  San Ramon district, 195 miles northeast of the...
# 3                                   Dailekh district
# ...

# %%
df.tail(5)
# Out:
#               source_name                                        source_link  \
# 11028    The Jakarta Post  http://www.thejakartapost.com/news/2017/04/02/...
# 11029     Greater Kashmir  http://www.greaterkashmir.com/news/jammu/lands...
# 11030           NBC Daily  http://www.nbcdaily.com/separate-landslides-ki...
# 11031  AGU Landslide Blog  http://blogs.agu.org/landslideblog/2017/05/02/...
# 11032  The Times of India  https://timesofindia.indiatimes.com/city/hyder...
#
#        event_id              event_date  event_time  \
# 11028     11109  04/01/2017 01:34:00 PM         NaN
# 11029     10845  03/25/2017 05:32:00 PM         NaN
# 11030     10973  12/15/2016 05:00:00 AM         NaN
# 11031     10901  04/29/2017 07:03:00 PM         NaN
# 11032     10949  03/13/2017 02:32:00 PM         NaN
#
#                                              event_title  \
# 11028                         Major landslide in Banaran
# 11029                            Barnari Sigdi Landslide
# ...

# %%
df.columns
# Out:
# Index(['source_name', 'source_link', 'event_id', 'event_date', 'event_time',
#        'event_title', 'event_description', 'location_description',
#        'location_accuracy', 'landslide_category', 'landslide_trigger',
#        'landslide_size', 'landslide_setting', 'fatality_count', 'injury_count',
#        'storm_name', 'photo_link', 'notes', 'event_import_source',
#        'event_import_id', 'country_name', 'country_code',
#        'admin_division_name', 'admin_division_population',
#        'gazeteer_closest_point', 'gazeteer_distance', 'submitted_date',
#        'created_date', 'last_edited_date', 'longitude', 'latitude'],
#       dtype='object')

# %%
print(df.iloc[4])
# Out:
# source_name                                                        The Freeman
# source_link                  http://www.philstar.com/cebu-news/621414/lands...
# event_id                                                                  2603
# event_date                                                 2010-10-16 12:00:00
# event_time                                                                 NaN
# event_title                                    sitio Bakilid in barangay Lahug
# event_description            Another landslide in sitio Bakilid in barangay...
# location_description                           sitio Bakilid in barangay Lahug
# location_accuracy                                                          5km
# landslide_category                                                   landslide
# landslide_trigger                                             tropical_cyclone
# landslide_size                                                          medium
# ...

# %%
for index,row in df.head(11).iterrows(): 
    print(index,row['event_title'])
# Out:
# 0 Sigou Village, Loufan County, Shanxi Province
# 1 Lake Oswego, Oregon
# 2 San Ramon district, 195 miles northeast of the capital, Lima,
# 3 Dailekh district
# 4 sitio Bakilid in barangay Lahug
# 5 Paguite, Abuyog, Leyte
# 6 Pend Oreille County, State Route 20 near Usk, OR
# 7 3 killed in Acapulco
# 8 Warm Springs Road, Idaho
# 9 Lincang City, Yunnan, Yunnan-Tibet No. 214 highway.
# 10 Kunming, Yunnan

# %% [markdown]
# # Temporal Analysis:
#
# 1. How has the frequency of rainfall-triggered landslide events varied over time since 2007?

# %%
df.loc[:, 'event_date'] = pd.to_datetime(df['event_date'], format='%m/%d/%Y %I:%M:%S %p')
df = df[df['event_date'].dt.year >= 2007].copy()  
df.loc[:, 'year'] = df['event_date'].dt.year
events_per_year = df.groupby('year').size()
plt.figure(figsize=(10, 6))
events_per_year.plot(kind='line', marker='o', color='teal')
plt.title('Frequency of Rainfall-Triggered Landslide Events (2007-2016)')
plt.xlabel('Year')
plt.ylabel('Number of Events')
plt.grid(True)
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_39184\3751902359.py:1: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.loc[:, 'event_date'] = pd.to_datetime(df['event_date'], format='%m/%d/%Y %I:%M:%S %p')

# %% [markdown]
# 2. Are there any seasonal trends in landslide occurrences?

# %%
df['event_date'] = pd.to_datetime(df['event_date'], format='%m/%d/%Y %I:%M:%S %p')
df['month'] = df['event_date'].dt.month
events_per_month = df.groupby('month').size()
colors = ['blue', 'green', 'cyan', 'orange', 'purple', 'yellow', 'red', 'magenta', 'brown', 'pink', 'gray', 'lightblue']
plt.figure(figsize=(10, 6))
events_per_month.plot(kind='bar', color=colors)
plt.title('Seasonal Trends in Landslide Occurrences')
plt.xlabel('Month')
plt.ylabel('Number of Events')
plt.xticks(range(1, 13), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.grid(True)
plt.show()

# %% [markdown]
# # Spatial Analysis:
#
# 1. Which regions of the world have experienced the highest number of landslide events?

# %%
events_per_region = df['location_description'].value_counts()
top_regions = events_per_region.head(10)  
plt.figure(figsize=(10, 6))
top_regions.plot(kind='bar', color='coral')
plt.title('Regions with Highest Frequency of Landslide Events')
plt.xlabel('Region')
plt.ylabel('Number of Events')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# 2. Identify any geographical patterns or hotspots in landslide occurrences?

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='longitude', y='latitude', alpha=1)
plt.title('Geographical Distribution of Landslide Occurrences')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.grid(True)
plt.show()

# %% [markdown]
# 3. Have there been any significant impacts reported as a result of these landslides?

# %%
impact_attributes = ['fatality_count', 'injury_count']

if all(attribute in df.columns for attribute in impact_attributes):
    summary_stats = df[impact_attributes].sum()
    plt.figure(figsize=(10, 6))
    summary_stats.plot(kind='bar', color='indigo', alpha=0.7)
    plt.title('Summary of Landslide Impacts')
    plt.xlabel('Impact Type')
    plt.ylabel('Total Count')
    plt.grid(True)
    plt.xticks(rotation=45)
    plt.show()
    print("Summary of Landslide Impacts:")
    print(summary_stats)
else:
    print("One or more impact attributes are not available in the dataset.")
# Out:
# Summary of Landslide Impacts:
# fatality_count    31061.0
# injury_count       4029.0
# dtype: float64

# %% [markdown]
# # Longitudinal Analysis:
# 1. How has the reporting of landslide events evolved over time?

# %%
df['event_date'] = pd.to_datetime(df['event_date'])
df['year'] = df['event_date'].dt.year
events_per_year = df.groupby('year').size()
plt.figure(figsize=(10, 6))
events_per_year.plot(kind='line', color='slateblue', marker='o')
plt.title('Landslide Events Reported Over Time')
plt.xlabel('Year')
plt.ylabel('Number of Events')
plt.grid(True)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# 2. Are there any changes in reporting accuracy or data quality over the years?

# %%
df['year'] = pd.to_datetime(df['event_date']).dt.year
missing_values_percentage = df.groupby('year').apply(lambda x: x.isnull().mean()) * 100
plt.figure(figsize=(10, 6))
missing_values_percentage.plot(kind='line', marker='o')
plt.title('Percentage of Missing Values Over Time')
plt.xlabel('Year')
plt.ylabel('Percentage of Missing Values')
plt.grid(True)
plt.show()

# %% [markdown]
# The above visualization shows the percentage of missing values over time. The 'event_date' column is converted to datetime format, and the year is extracted. Then, the percentage of missing values for each year is calculated and plotted as a line graph.

# %% [markdown]
# # ---------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Summary-
# This project explored the Global Landslide Catalog dataset, investigating trends in reporting accuracy and data quality over time. Through temporal analysis and visualization, it revealed fluctuations in the percentage of missing values across different years. These findings shed light on the dataset's evolution and provide insights into potential improvements in reporting standards or data collection processes over the years.
